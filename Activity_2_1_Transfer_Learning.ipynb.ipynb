# %% [markdown]
# # Activity 2.1: Understanding Transfer Learning with MobileNetV2
#
# ## Objective
# To understand the concept of transfer learning and demonstrate it using a pre-trained MobileNetV2 model.

# %% [markdown]
# ## What is Transfer Learning?
#
# Transfer learning is a machine learning technique where a model trained on one task is reused as the starting point for a new but related task.
# It is widely used in deep learning to save time and improve performance.
#
# ## Why MobileNetV2?
#
# MobileNetV2 is a lightweight convolutional neural network designed for mobile and embedded applications.
# It uses depthwise separable convolutions and inverted residual blocks, making it efficient and accurate.

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

print("MobileNetV2 loaded successfully.")
# Out:
# MobileNetV2 loaded successfully.

# %%
base_model.trainable = False
print("Base model layers frozen.")
# Out:
# Base model layers frozen.

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
output = Dense(38, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

print("Transfer learning model created successfully.")
# Out:
# Transfer learning model created successfully.

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ...

# %% [markdown]
# ## Conclusion
#
# In this activity, transfer learning using MobileNetV2 was studied.
# The pre-trained model was reused by freezing its base layers and adding new classification layers.
# This approach reduces training time and improves efficiency.
